# %%
#027
num = float(input("Enter a number with lots of decimal places:  "))
print(num*2)
# Out:
# Enter a number with losts of decimal places:  1.5
# 3.0

# %%
#028
num = float(input("Enter a number with lots of decimal places: "))
answer = num*2
print(answer)
print(round(answer, 2))
# Out:
# Enter a number with lots of decimal places: 1.5
# 3.0
# 3.0

# %%
#029
import math
num = int(input("enter a number over 500: "))
answer = math.sqrt(num)
print(round(answer,2))
# Out:
# enter a number over 500: 568
# 23.83

# %%
#030
import math
print(round(math.pi, 5))
# Out:
# 3.14159

# %%
#031
import math
radius = int(input("Enter the radius of the circle: "))
area = math.pi*(radius**2)
print(area)
# Out:
# Enter the radius of the circle: 48
# 7238.229473870883

# %%
#032
import math
radius = int(input('Enter the radius of the circle: '))
depth = int(input('Enter depth: '))
area = math.pi*(radius**2)
volume = area*depth
print(round(volume,3))
# Out:
# Enter the radius of the circle: 25
# Enter depth: 5
# 9817.477

# %%
#033
num1 = int(input("Enter a numbre: "))
num2 = int(input("Entre another number: "))
ans1 = num1 / num2
ans2 = num1 % num2
print(num1, "divided by", num2, "is", ans1, "with", ans2, "reaming.")
# Out:
# Enter a numbre: 10
# Entre another number: 3
# 10 divided by 3 is 3.3333333333333335 with 1 reaming.

# %%
#034
print('1) Square')
print('2) Triangle')
print()
menuselection = int(input("Enter a number: "))
if menuselection == 1:
  side = int(input("Enter the lenth of one side: "))
  area = side*side
elif menuselection == 2:
  base = int(input("Enter the lenth of the base: "))
  height = int(input("Enter the heignt of the triangle: "))
  area = (base*height)/2
  print("The area of your chosen shape is", area)
else:
  print('Incorrect option selected')
# Out:
# 1) Square
# 2) Triangle
#
# Enter a number: 2
# Enter the lenth of the base: 14
# Enter the heignt of the triangle: 23
# The area of your chosen shape is 161.0
