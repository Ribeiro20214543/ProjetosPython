# %%
#012
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
if num1 > num2:
  print(num2, num1)
else:
  print(num1, num2)
# Out:
# Enter first number: 12
# Enter second number: 16
# 12 16

# %%
#013
num = int(input("Enter a value less tha 20: "))
if num >= 20:
  print("Too high")
else:
  print('Thank you')
# Out:
# Enter a value less tha 20: 12
# Thank you

# %%
#014
num = int(input("Enter a value between 10 an 20: "))
if num >= 10 and num <= 20:
  print("Thank you")
else:
  print("Incorret answer")
# Out:
# Enter a value between 10 an 20: 15
# Thank you

# %%
#015
colour = input("Type in your favourite colour: ")
if colour == 'red' or colour == 'RED' or colour == 'Red':
  print("I like red too.")
else:
  print("I don't like that colour, I prefer red.")
# Out:
# Type in your favourite colour: blue
# I don't like that colour, I prefer red.

# %%
#016
raining = input("Is it raining? ")
raining = str.lower(raining)
if raining =="yes":
  windy = input("Is it windy? ")
  windy = str.lower(windy)
  if windy == "yes":
    print("It is too windy for an umbrella")
  else:
    print("Take an umbrella")
else:
  print("Enjoy your day")
# Out:
# Is it raining? Yes
# Is it windy? Yes
# It is too windy for an umbrella

# %%
#017
age = int(input("What is your age? "))
if age >= 18:
  print("You can learn to drive")
elif age == 17:
  print("You can vote")
elif age == 16:
  print("You can buy a lottery ticket")
else:
  print("You can go Trick-or-Treating")
# Out:
# What is your age? 41
# You can learn to drive

# %%
#018
num = int(input("Enter a number: "))
if num < 10:
  print("Too low")
elif num >= 10 and num <= 20:
  print("Correct")
else:
  print("Too high")
# Out:
# Enter a number: 16
# Correct

# %%
#019
num = input("Enter 1, 2 or 3: ")
if num == "1":
  print("Thank you")
elif num == "2":
  print("Well done")
elif num == "3":
  print("Correct")
else:
  print("Error message")
# Out:
# Enter 1, 2 or 3: 2
# Well done
