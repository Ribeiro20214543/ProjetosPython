# %%
#01
firstname = input("Please enter your first name: ")
print("Hello", firstname)
# Out:
# Please enter your first name: Patrick
# Hello Patrick

# %%
#02
surname = input("Please enter your surname: ")
print("Hello", firstname, surname)
# Out:
# Please enter your surname: Ribeiro
# Hello Patrick Ribeiro

# %%
#03
print("What do you call a bear with no teeth?\n A gummy bear!")
# Out:
# What do you call a bear with no teeth?
#  A gummy bear!

# %%
#04
num1 = int(input("Please enter your first number: "))
num2 = int (input("Please enter your second number: "))
answer = num1 + num2
print("The answer is", answer)
# Out:
# Please enter your first number: 19
# Please enter your second number: 80
# The answer is 99

# %%
#05
num3 = int(input("Please enter your third number: "))
answer = (num1 + num2) * num3
print("The answer is", answer)
# Out:
# Please enter your third number: 41
# The answer is 4059

# %%
#06
startNum = int(input("Enter the number of slices of pizza you started with: "))
endNum = int(input("How many slices have you eaten? "))
slicesLeft = startNum - endNum
print("You have", slicesLeft, "slices remaining")
# Out:
# Enter the number of slices of pizza you started with: 8
# How many slices have you eaten? 3
# You have 5 slices remaining

# %%
#07
name = input("What is your name? ")
age = int(input("How old are you? "))
newAge = age + 1
print(name,  "next birthday you will be", newAge)
# Out:
# What is your name? Patrick
# How old are you? 41
# Patrick next birthday you will be 42

# %%
#08
bill = int(input("What is the total cost of the bill? "))
people = int(input("How many people are there? "))
each = bill/people
print("Each person should pay U$", each)
# Out:
# What is the total cost of the bill? 135
# How many people are there? 5
# Each person should pay U$ 27.0

# %%
#09
days = int(input("Enter the number of days: "))
hours = days * 24
minutes = hours * 60
seconds = minutes * 60
print("In", days, "days there are...")
print(hours, "hours")
print(minutes, "minutes")
print(seconds, "seconds")
# Out:
# Enter the number of days: 26
# In 26 days there are...
# 624 hours
# 37440 minutes
# 2246400 seconds

# %%
#010
kilo = int(input("Enter the number of kilos: "))
pound = kilo * 2.204
print("That is", pound, "pounds")
# Out:
# Enter the number of kilos: 42
# That is 92.56800000000001 pounds

# %%
#011
larger = int (input("Enter the number over 100: "))
smaller = int(input("Enter a number under 10: "))
answer = larger / smaller
print(smaller, "goes into", larger, answer, "times")
# Out:
# Enter the number over 100: 56
# Enter a number under 10: 4
# 4 goes into 56 14.0 times
