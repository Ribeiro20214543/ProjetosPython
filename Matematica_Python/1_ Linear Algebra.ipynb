# %%
# use np.array() to create the arrays and multiplications --> an example creating 2x2 arrays:

import numpy as np

a = np.array([[0,1],[1,2]])
b = np.array([[1,1],[1,5]])
c = np.array([[3,-1],[4,2]])
d = np.array([[8,1],[1,2]])
e = np.array([[2,2],[-3,1]])

print(a*b)
print()
print(c*e)
# Out:
# [[ 0  1]
#  [ 1 10]]
#
# [[  6  -2]
#  [-12   2]]

# %%
# Given the matrix of the exercise, calculate the inverse and transpose

import numpy as np

a = np.array([[1,0,0],[-1/2, 0, 1/2],[1/2, 1, -3/2]])
inv = np.linalg.inv(a)
tr = a.T

print(inv)
print()
print(tr)
# Out:
# [[1. 0. 0.]
#  [1. 3. 1.]
#  [1. 2. 0.]]
#
# [[ 1.  -0.5  0.5]
#  [ 0.   0.   1. ]
#  [ 0.   0.5 -1.5]]

# %%
import numpy as np

a = np.array([[1,3,1],[5, 2, 1],[3, 1, 1]])
y = np.array([[1],[0],[1]])
inv = np.linalg.inv(a)
result = np.dot(inv,y)

print(result)
# Out:
# [[-0.33333333]
#  [-0.33333333]
#  [ 2.33333333]]

# %%
res = np.linalg.solve(a,y)
print(res)
# Out:
# [[-0.33333333]
#  [-0.33333333]
#  [ 2.33333333]]

# %%
det = np.linalg.det(a)
print(det)
# Out:
# -6.0

# %%
from plot_helper import *
import numpy

baseA = numpy.array([(-2,1),(1,-3)])
plot_linear_transformation(baseA)

# %%
import numpy as np
matriz = np.array([
[1,0,2,1],
[-3,4,-1,0],
[-1,2,2,-2],
[0,1,-1,1]
])
autovalores, autovetores = np.linalg.eig(matriz)
print(autovalores)
print()
print(autovetores)
# Out:
# [-0.64649043+0.j          3.14054186+1.96711783j  3.14054186-1.96711783j
#   2.36540671+0.j        ]
#
# [[ 0.71687222+0.j         -0.08629941+0.38375763j -0.08629941-0.38375763j
#    0.40181321+0.j        ]
#  [ 0.38470745+0.j         -0.7502425 +0.j         -0.7502425 -0.j
#    0.74050023+0.j        ]
#  [-0.36307721+0.j         -0.38590379+0.32454251j -0.38590379-0.32454251j
#    0.00497708+0.j        ]
#  [-0.45416884+0.j         -0.1678164 +0.00260314j -0.1678164 -0.00260314j
#    0.5386843 +0.j        ]]

# %%
matrizDiagonal = np.diag(autovalores)
print(matrizDiagonal)
# Out:
# [[-0.64649043+0.j          0.        +0.j          0.        +0.j
#    0.        +0.j        ]
#  [ 0.        +0.j          3.14054186+1.96711783j  0.        +0.j
#    0.        +0.j        ]
#  [ 0.        +0.j          0.        +0.j          3.14054186-1.96711783j
#    0.        +0.j        ]
#  [ 0.        +0.j          0.        +0.j          0.        +0.j
#    2.36540671+0.j        ]]

# %%
import numpy as np
A = np.array([[50/100, 10/100, 20/100, 30/100],
[10/100, 20/100, 30/100, 30/100],
[10/100, 50/100, 20/100, 20/100],
[30/100, 20/100, 30/100, 20/100]])
w = np.array([[0],
[1],
[0],
[0]])

# %%
# função que realizará a mudança de estado até o ano a ser definido
def estado(matrizTransicao, vetorEstado, transicao):
# estrutura de repetição for de 0 até (anos - 1)
    for indice in range(0, transicao):
# realiza o calculo definido no teorema acima
        vetorEstado = np.dot(matrizTransicao, vetorEstado)
# retorna o vetor estado após sofrer todas as mudanças de estado até o ano informado
    return vetorEstado

# %%
# vetor-estado após a 1º observação
print("O vetor-estado na 1º observação é: \n\n{}".format(estado(A, w,
transicao = 1)))
# Out:
# O vetor-estado na 1º observação é:
#
# [[0.1]
#  [0.2]
#  [0.5]
#  [0.2]]

# %%
# vetor-estado após a 2º observação
print("O vetor-estado na 2º observação é:\n\n{}".format(estado(A, w, transicao = 2)))
# Out:
# O vetor-estado na 2º observação é:
#
# [[0.23]
#  [0.26]
#  [0.25]
#  [0.26]]

# %%
# vetor-estado após a 11º observação
print("O vetor-estado na 11º observação é: \n\n{}".format(estado(A, w, transicao = 11)))
# Out:
# O vetor-estado na 11º observação é:
#
# [[0.29039567]
#  [0.21992943]
#  [0.23694151]
#  [0.25273339]]

# %%
# vetor-estado após a 11º observação
print("O vetor-estado na 11º observação é: \n\n{}".format(estado(A, w, transicao = 20)))
# Out:
# O vetor-estado na 11º observação é:
#
# [[0.29040097]
#  [0.2199271 ]
#  [0.23693803]
#  [0.2527339 ]]
